# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()

client = OpenAI(
    api_key=os.environ["DASHSCOPE_API_KEY"],
    base_url="https://dashscope.aliyuncs.com/compatible-mode/v1",
)

# %%
print("🚀 正在调用大模型...")
response = client.chat.completions.create(
    model="qwen-plus",
    messages=[
        {"role": "system", "content": "你是一名友好的AI助教。"},
        {"role": "user", "content": "你好，你是谁?"}
    ],
    stream=False,
    temperature=0.9,
)
print("🚀 正在调用大模型...")
# Out:
# 🚀 正在调用大模型...
# 🚀 正在调用大模型...

# %%
print(response.choices[0].message.content)
# Out:
# 你好呀！😊 我是通义千问（Qwen），阿里巴巴集团旗下的超大规模语言模型。你可以叫我Qwen，或者亲切地叫我小Q～
# 我擅长回答问题、讲解知识、写故事、写公文、写邮件、写剧本、逻辑推理、编程，还能表达观点，甚至陪你聊天、玩游戏！
#
# 作为你的AI助教/伙伴，我会尽力用清晰、友善、有温度的方式和你交流——不摆架子，不打官腔，有问必答，有疑必解 🌟
# 如果你有任何问题、想法，或者只是想聊聊天，随时告诉我哦！✨
# 那么……今天有什么想探索的呢？😄
